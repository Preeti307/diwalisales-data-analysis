# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Diwali Sales Data.csv", encoding="latin1")
print(df.to_string())
# Out:
#        User_ID      Cust_name Product_ID Gender Age Group  Age  Marital_Status             State      Zone       Occupation       Product_Category  Orders    Amount  Status  unnamed1
# 0      1002903      Sanskriti  P00125942      F     26-35   28               0       Maharashtra   Western       Healthcare                   Auto       1  23952.00     NaN       NaN
# 1      1000732         Kartik  P00110942      F     26-35   35               1    Andhra Pradesh  Southern             Govt                   Auto       3  23934.00     NaN       NaN
# 2      1001990          Bindu  P00118542      F     26-35   35               1     Uttar Pradesh   Central       Automobile                   Auto       3  23924.00     NaN       NaN
# 3      1001425         Sudevi  P00237842      M      0-17   16               0         Karnataka  Southern     Construction                   Auto       2  23912.00     NaN       NaN
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='str')

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.3 MB

# %%
df.isna().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df = df.drop(["Status","unnamed1"],axis=1)
df.shape
# Out:
# (11251, 13)

# %%
df.isna().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (11239, 13)

# %%
df.isna().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df["Amount"].dtype
# Out:
# dtype('float64')

# %%
df["Amount"] = df["Amount"].astype("int")

# %%
df["Amount"].dtype
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='str')

# %%
df.rename(columns={"Marital_Status":"Shadi"})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28      0
# 1      1000732       Kartik  P00110942      F     26-35   35      1
# 2      1001990        Bindu  P00118542      F     26-35   35      1
# 3      1001425       Sudevi  P00237842      M      0-17   16      0
# 4      1000588         Joni  P00057942      M     26-35   28      1
# ...        ...          ...        ...    ...       ...  ...    ...
# 11246  1000695      Manning  P00296942      M     18-25   19      1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33      0
# 11248  1001209        Oshin  P00201342      F     36-45   40      0
# 11249  1004023       Noonan  P00059442      M     36-45   37      0
# 11250  1002744      Brumley  P00281742      F     18-25   19      0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
ax = sns.countplot(data=df,x="Gender")

# %%
ax = sns.countplot(data=df,x="Gender",hue="Gender")
for bar in ax.containers:
    ax.bar_label(bar)

# %%
sales_gen = df.groupby("Gender", as_index=False)["Amount"].sum().sort_values(by="Amount", ascending=False)

sns.barplot(data=sales_gen, x="Gender", y="Amount",hue="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='str')

# %%
ax = sns.countplot(data=df, x="Age Group", hue="Gender")
for bar in ax.containers:
    ax.bar_label(bar)

# %%
plt.figure(figsize=(12, 6), constrained_layout=True)
sales_gen = df.groupby("Age Group",as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
ax = sns.barplot(data=sales_gen,x="Age Group",y="Amount" , palette="Set2")
for bar in ax.containers:
    ax.bar_label(bar)
# Out:
# C:\Users\PREETI KHATRI\AppData\Local\Temp\ipykernel_2256\1354627267.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=sales_gen,x="Age Group",y="Amount" , palette="Set2")

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='str')

# %%
plt.figure(figsize=(20,7),constrained_layout=True)
sales_state = df.groupby("State", as_index=False)["Orders"].sum().sort_values(by="Orders", ascending=False)
plt.grid(ls='-.')

ax = sns.barplot(data=sales_state, x="State", y="Orders")

for bar in ax.containers:
    ax.bar_label(bar)

# %%
plt.figure(figsize=(20,7),constrained_layout=True)
sales_state = df.groupby("State", as_index=False)["Amount"].sum().sort_values(by="Amount", ascending=False)
# plt.grid(ls='-.')

ax = sns.barplot(data=sales_state, x="State", y="Amount")

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='str')

# %%
ax = sns.countplot(data=df, x="Marital_Status",hue="Gender")
for bar in ax.containers:
    ax.bar_label(bar)

# %%
# plt.figure(figsize=(20,7),constrained_layout=True)
sales_state = df.groupby("Marital_Status", as_index=False)["Orders"].sum().sort_values(by="Orders", ascending=False)
# plt.grid(ls='-.')

ax = sns.barplot(data=sales_state, x="Marital_Status", y="Orders")

for bar in ax.containers:
    ax.bar_label(bar)

# %%
sales_state = df.groupby(["Marital_Status","Gender"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
sns.barplot(data=sales_state, x="Marital_Status",y="Amount",hue="Gender")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
plt.figure(figsize=(20,7),constrained_layout=True)
# sales_state = df.groupby(["State","Gender"],as_index=False)["Marital_Status"].sum().sort_values(by="Marital_Status",ascending=False)
sales_state = df.groupby("State",as_index=False)["Marital_Status"].sum().sort_values(by="Marital_Status",ascending=False)
ax = sns.barplot(data=sales_state, x="State",y="Marital_Status",hue="Marital_Status")
for bar in ax.containers:
    ax.bar_label(bar)
